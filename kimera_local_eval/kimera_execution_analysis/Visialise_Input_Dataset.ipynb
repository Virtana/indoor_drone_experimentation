# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %%
base_dir = '/home/shiva/Datasets/'
working_dir = 'mav0'

df_imu_custom = pd.read_csv(f'{base_dir}/{working_dir}/imu0/data.csv')

# %%
df_imu_custom
# Out:
#            #timestamp [ns]  w_RS_S_x [rad s^-1]  w_RS_S_y [rad s^-1]  \
# 0      1740757907072335872            -0.004261             0.008522
# 1      1740757907077107968            -0.004261             0.002131
# 2      1740757907081982976             0.002131            -0.005326
# 3      1740757907087270912             0.001065            -0.004261
# 4      1740757907092497152            -0.002131            -0.003196
# ...                    ...                  ...                  ...
# 12014  1740757967132529920             0.002131            -0.018109
# 12015  1740757967137708800            -0.002131            -0.012783
# 12016  1740757967142221056            -0.000000            -0.014914
# 12017  1740757967147546112            -0.003196            -0.017044
# 12018  1740757967152194048             0.003196            -0.012783
#
#        w_RS_S_z [rad s^-1]  a_RS_S_x [m s^-2]  a_RS_S_y [m s^-2]  \
# 0                 0.001065           -9.67257           -0.91937
# ...

# %%
g = sns.lineplot(x='#timestamp [ns]', y='a_RS_S_z [m s^-2]', data=df_imu_custom)

# %%
base_dir = '/home/shiva/Datasets/Euroc_Datasets'
working_dir = 'V2_01_easy/mav0/imu0'

df_imu_euroc = pd.read_csv(f'{base_dir}/{working_dir}/data.csv')

# %%
df_imu_euroc
# Out:
#            #timestamp [ns]  w_RS_S_x [rad s^-1]  w_RS_S_y [rad s^-1]  \
# 0      1413393212225760512             0.094946             0.020246
# 1      1413393212230760448             0.058643             0.035605
# 2      1413393212235760384            -0.011170             0.027925
# 3      1413393212240760576            -0.072606             0.033510
# 4      1413393212245760512            -0.092153             0.036303
# ...                    ...                  ...                  ...
# 22795  1413393326200760576             0.005585             0.023736
# 22796  1413393326205760512             0.004887             0.027925
# 22797  1413393326210760448             0.002793             0.023736
# 22798  1413393326215760384            -0.002793             0.028623
# 22799  1413393326220760576            -0.005585             0.024435
#
#        w_RS_S_z [rad s^-1]  a_RS_S_x [m s^-2]  a_RS_S_y [m s^-2]  \
# 0                 0.058643           9.128357           0.106239
# ...

# %%
g = sns.lineplot(x='#timestamp [ns]', y='a_RS_S_z [m s^-2]', data=df_imu_euroc)
