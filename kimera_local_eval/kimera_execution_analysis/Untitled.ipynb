# %%
import pandas as pd

# %%
base_dir = '/home/shiva/Datasets/'
working_dir = 'mav0'

full_dir_path = f'{base_dir}/{working_dir}/imu0/data.csv'

# %%
df = pd.read_csv(full_dir_path)

# %%
df
# Out:
#            #timestamp [ns]  w_RS_S_x [rad s^-1]  w_RS_S_y [rad s^-1]  \
# 0      1740757289020826112            -0.004261            -0.002131
# 1      1740757289025516032             0.004261             0.001065
# 2      1740757289030458880             0.003196            -0.003196
# 3      1740757289035880192            -0.001065            -0.003196
# 4      1740757289040805120            -0.002131            -0.009587
# ...                    ...                  ...                  ...
# 14014  1740757359077177088            -0.005326             0.008522
# 14015  1740757359082138112            -0.003196             0.008522
# 14016  1740757359087499008            -0.004261            -0.002131
# 14017  1740757359092647936            -0.005326            -0.002131
# 14018  1740757359097435904             0.002131            -0.002131
#
#        w_RS_S_z [rad s^-1]  a_RS_S_x [m s^-2]  a_RS_S_y [m s^-2]  \
# 0                -0.004261           -9.68215           -0.85234
# ...

# %%
cols = list(df.columns)

# %%
cols
# Out:
# ['#timestamp [ns]',
#  'w_RS_S_x [rad s^-1]',
#  'w_RS_S_y [rad s^-1]',
#  'w_RS_S_z [rad s^-1]',
#  'a_RS_S_x [m s^-2]',
#  'a_RS_S_y [m s^-2]',
#  'a_RS_S_z [m s^-2]']

# %%
del cols[0]

# %%
del cols[0]

# %%
del cols[0]

# %%
del cols[1]

# %%
del cols[1]

# %%
cols
# Out:
# ['w_RS_S_z [rad s^-1]', 'a_RS_S_z [m s^-2]']

# %%
for col in cols:
    df[col] = df[col] * -1

# %%
df
# Out:
#            #timestamp [ns]  w_RS_S_x [rad s^-1]  w_RS_S_y [rad s^-1]  \
# 0      1740757289020826112            -0.004261            -0.002131
# 1      1740757289025516032             0.004261             0.001065
# 2      1740757289030458880             0.003196            -0.003196
# 3      1740757289035880192            -0.001065            -0.003196
# 4      1740757289040805120            -0.002131            -0.009587
# ...                    ...                  ...                  ...
# 14014  1740757359077177088            -0.005326             0.008522
# 14015  1740757359082138112            -0.003196             0.008522
# 14016  1740757359087499008            -0.004261            -0.002131
# 14017  1740757359092647936            -0.005326            -0.002131
# 14018  1740757359097435904             0.002131            -0.002131
#
#        w_RS_S_z [rad s^-1]  a_RS_S_x [m s^-2]  a_RS_S_y [m s^-2]  \
# 0                 0.004261           -9.68215           -0.85234
# ...

# %%
df.to_csv(f'{base_dir}/{working_dir}/imu0/data_inverted.csv', index=False)
