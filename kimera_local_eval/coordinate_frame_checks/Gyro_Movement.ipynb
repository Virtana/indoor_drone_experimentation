# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %%
dir_name = 'gyro_z_new'

df = pd.read_csv(f'../data/coordinate_frame_checks/{dir_name}/imu0/gyro_data.csv')

# %%
df
# Out:
#              #timestamp [ns]  w_RS_S_x [rad s^-1]  w_RS_S_y [rad s^-1]  \
# 0     0 days 00:00:01.318573             0.020240             0.020240
# 1     0 days 00:00:01.323257             0.022371             0.037284
# 2     0 days 00:00:01.328302             0.015979             0.038350
# 3     0 days 00:00:01.333332            -0.000000             0.040480
# 4     0 days 00:00:01.338543            -0.017044             0.037284
# ...                      ...                  ...                  ...
# 1994  0 days 00:00:11.284390            -0.030893            -0.010653
# 1995  0 days 00:00:11.289868            -0.028762            -0.019175
# 1996  0 days 00:00:11.294797            -0.015979            -0.027697
# 1997  0 days 00:00:11.299722            -0.007457            -0.021305
# 1998  0 days 00:00:11.304439            -0.001065            -0.010653
#
#       w_RS_S_z [rad s^-1]
# 0               -0.063916
# 1               -0.070307
# 2               -0.051133
# 3               -0.029827
# 4               -0.018109
# ...                   ...
# 1994             0.002131
# 1995            -0.010653
# 1996            -0.022371
# 1997            -0.028762
# 1998            -0.039415
#
# [1999 rows x 4 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   #timestamp [ns]      1999 non-null   object
#  1   w_RS_S_x [rad s^-1]  1999 non-null   float64
#  2   w_RS_S_y [rad s^-1]  1999 non-null   float64
#  3   w_RS_S_z [rad s^-1]  1999 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 62.6+ KB

# %%
df.head(5)
# Out:
#           #timestamp [ns]  w_RS_S_x [rad s^-1]  w_RS_S_y [rad s^-1]  \
# 0  0 days 00:00:01.318573             0.020240             0.020240
# 1  0 days 00:00:01.323257             0.022371             0.037284
# 2  0 days 00:00:01.328302             0.015979             0.038350
# 3  0 days 00:00:01.333332            -0.000000             0.040480
# 4  0 days 00:00:01.338543            -0.017044             0.037284
#
#    w_RS_S_z [rad s^-1]
# 0            -0.063916
# 1            -0.070307
# 2            -0.051133
# 3            -0.029827
# 4            -0.018109

# %%
def remove_days(date_str):
    return date_str[7:]

# %%
df['#timestamp [ns]'] = df['#timestamp [ns]'].apply(remove_days)

# %%
df['#timestamp [ns]'] = pd.to_timedelta(df['#timestamp [ns]'])

# %%
df.head(5)
# Out:
#          #timestamp [ns]  w_RS_S_x [rad s^-1]  w_RS_S_y [rad s^-1]  \
# 0 0 days 00:00:01.318573             0.020240             0.020240
# 1 0 days 00:00:01.323257             0.022371             0.037284
# 2 0 days 00:00:01.328302             0.015979             0.038350
# 3 0 days 00:00:01.333332            -0.000000             0.040480
# 4 0 days 00:00:01.338543            -0.017044             0.037284
#
#    w_RS_S_z [rad s^-1]
# 0            -0.063916
# 1            -0.070307
# 2            -0.051133
# 3            -0.029827
# 4            -0.018109

# %%
df['#timestamp [ns]'] = df['#timestamp [ns]'].dt.total_seconds()

# %%
sns.set_theme(rc={'figure.figsize':(20,8)})

# %%
col_to_investigate = 'w_RS_S_z [rad s^-1]'

# %%
sns.lineplot(data=df, x='#timestamp [ns]', y=col_to_investigate)
# Out:
# <Axes: xlabel='#timestamp [ns]', ylabel='w_RS_S_z [rad s^-1]'>

# %%
sns.lineplot(data=df[000:500], x='#timestamp [ns]', y=col_to_investigate)
# Out:
# <Axes: xlabel='#timestamp [ns]', ylabel='w_RS_S_z [rad s^-1]'>

# %%
df.describe()
# Out:
#        #timestamp [ns]  w_RS_S_x [rad s^-1]  w_RS_S_y [rad s^-1]  \
# count      1999.000000          1999.000000          1999.000000
# mean          6.366769             0.000444            -0.003787
# std           2.884792             0.003487             0.002552
# min           1.374058            -0.011718            -0.013848
# 25%           3.870318            -0.002131            -0.005326
# 50%           6.366508             0.000000            -0.004261
# 75%           8.863156             0.003196            -0.002131
# max          11.359335             0.012783             0.004261
#
#        w_RS_S_z [rad s^-1]
# count          1999.000000
# mean              0.000260
# std               0.002804
# min              -0.011718
# 25%              -0.002131
# 50%               0.000000
# 75%               0.002131
# max               0.009587

# %%
sns.lineplot(data=df[500:1000], x='#timestamp [ns]', y=col_to_investigate)
# Out:
# <Axes: xlabel='#timestamp [ns]', ylabel='w_RS_S_z [rad s^-1]'>

# %%
sns.lineplot(data=df[1000:1500], x='#timestamp [ns]', y=col_to_investigate)
# Out:
# <Axes: xlabel='#timestamp [ns]', ylabel='w_RS_S_z [rad s^-1]'>

# %%
sns.lineplot(data=df[1500:2000], x='#timestamp [ns]', y=col_to_investigate)
# Out:
# <Axes: xlabel='#timestamp [ns]', ylabel='w_RS_S_z [rad s^-1]'>
